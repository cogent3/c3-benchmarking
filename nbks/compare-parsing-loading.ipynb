# %% [markdown]
# # Notation
#
# - `bp` - biopython
# - `c3` - cogent3
# - `c3h5s` - sparse storage from cogent3-h5seqs plugin
# - `sb` - scikit-bio

# %% [markdown]
# # Comparing performance of raw parsers of basic data formats
#
# ## Parse Fasta
#
# ### Human chromosome 1

# %%
from c3bench.report import display_results_for

display_results_for("parse_fasta", "hsap_fa")
# Out:
# =================================================================================================
# Function    Result Type    mean(time) seconds    std(time) seconds    mean(RAM)    std(RAM) bytes
# -------------------------------------------------------------------------------------------------
# bp                   OK                  0.88                 0.00       1.0 GB              0.00
# c3                   OK                  0.55                 0.00       1.2 GB              0.00
# sb                   OK                  4.90                 0.01       1.6 GB        419,101.74
# -------------------------------------------------------------------------------------------------

# %% [markdown]
# ### SARS multiple sequence alignment

# %%
display_results_for("parse_fasta", "sars_msa")
# Out:
# =================================================================================================
# Function    Result Type    mean(time) seconds    std(time) seconds    mean(RAM)    std(RAM) bytes
# -------------------------------------------------------------------------------------------------
# bp                   OK                  6.75                 0.03       2.5 GB        406,750.19
# c3                   OK                  3.87                 0.02       7.3 GB              0.00
# sb                   OK                 20.95                 0.09       2.6 GB        501,343.26
# -------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Parse GenBank
#
# ### Human chromosome 1

# %%
display_results_for("parse_gbk", "hsap_gbk")
# Out:
# =================================================================================================
# Function    Result Type    mean(time) seconds    std(time) seconds    mean(RAM)    std(RAM) bytes
# -------------------------------------------------------------------------------------------------
# bp                   OK                  6.09                 0.04       1.4 GB              0.00
# c3                   OK                  6.52                 0.02       2.3 GB              0.00
# sb                Error                  3.32                 0.03     851.9 MB              0.00
# -------------------------------------------------------------------------------------------------

# %% [markdown]
# ### A microbial genome

# %%
display_results_for("parse_gbk", "micro_gbk")
# Out:
# =================================================================================================
# Function    Result Type    mean(time) seconds    std(time) seconds    mean(RAM)    std(RAM) bytes
# -------------------------------------------------------------------------------------------------
# bp                   OK                  0.59                 0.00     110.5 MB              0.00
# c3                   OK                  0.61                 0.01     184.2 MB              0.00
# sb                   OK                  1.98                 0.01     279.9 MB              0.00
# -------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Parse GFF3
#
# ### Human genome

# %%
display_results_for("parse_gff", "hsap_gff3")
# Out:
# =================================================================================================
# Function    Result Type    mean(time) seconds    std(time) seconds    mean(RAM)    std(RAM) bytes
# -------------------------------------------------------------------------------------------------
# bp                   OK                 79.13                 0.29      10.0 GB              0.00
# c3                   OK                  5.33                 0.02       2.5 GB              0.00
# c3db                 OK                 89.12                 0.30       4.0 GB      2,345,908.09
# sb                   OK                 66.24                 0.12       6.2 GB        283,779.20
# -------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Loading an alignment
#
# ### Loading SARS-COV-2

# %%
display_results_for("load_aln")
# Out:
# ========================================================================================================
# Function           Result Type    mean(time) seconds    std(time) seconds    mean(RAM)    std(RAM) bytes
# --------------------------------------------------------------------------------------------------------
# bp                          OK                  7.07                 0.32       2.5 GB              0.00
# c3                          OK                  8.07                 0.06       7.3 GB              0.00
# c3h5s                       OK                 18.89                 0.19       7.3 GB              0.00
# c3h5s_formatted             OK                  0.71                 0.01     173.9 MB              0.00
# sb                          OK                 29.78                 0.12       2.6 GB              0.00
# --------------------------------------------------------------------------------------------------------
